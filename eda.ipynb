# %%
import pandas as pd

# %%
df = pd.read_csv('data/raw/raw_page_001.csv', header=0)

# %%
df.describe()
# Out:
#           ridership      transfers       latitude      longitude
# count  500000.00000  500000.000000  500000.000000  500000.000000
# mean       67.08699       2.313608      40.732983     -73.934890
# std       213.82253      16.932774       0.079160       0.056125
# min         1.00000       0.000000      40.576126     -74.074840
# 25%         5.00000       0.000000      40.677315     -73.980660
# 50%        16.00000       0.000000      40.724330     -73.947150
# 75%        57.00000       1.000000      40.796093     -73.899230
# max     12071.00000    1789.000000      40.903126     -73.755400

# %%
df.dtypes
# Out:
# transit_timestamp          str
# transit_mode               str
# station_complex_id         str
# station_complex            str
# borough                    str
# payment_method             str
# fare_class_category        str
# ridership              float64
# transfers              float64
# latitude               float64
# longitude              float64
# georeference               str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   transit_timestamp    500000 non-null  str
#  1   transit_mode         500000 non-null  str
#  2   station_complex_id   500000 non-null  str
#  3   station_complex      500000 non-null  str
#  4   borough              500000 non-null  str
#  5   payment_method       500000 non-null  str
#  6   fare_class_category  500000 non-null  str
#  7   ridership            500000 non-null  float64
#  8   transfers            500000 non-null  float64
#  9   latitude             500000 non-null  float64
#  10  longitude            500000 non-null  float64
#  11  georeference         500000 non-null  str
# dtypes: float64(4), str(8)
# memory usage: 45.8 MB

# %%
df['transit_timestamp'] = pd.to_datetime(df['transit_timestamp'])

# %%
df['date'] = df['transit_timestamp'].dt.date

# %%
df['hour'] = df['transit_timestamp'].dt.hour

# %%
df['Weekday'] = df['transit_timestamp'].dt.day_name()

# %%
df['ridership'].describe()
# Out:
# count    500000.00000
# mean         67.08699
# std         213.82253
# min           1.00000
# 25%           5.00000
# 50%          16.00000
# 75%          57.00000
# max       12071.00000
# Name: ridership, dtype: float64

# %%
print(f"{len(df):,}")
# Out:
# 500,000
